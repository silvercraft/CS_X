# %%
# -*- coding: utf-8 -*-
"""
Spyder Editor

This is a temporary script file.
"""
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import TreebankWordTokenizer
from nltk.tag import pos_tag
from nltk import ne_chunk, Tree
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')
#nltk.download('maxent_ne_chunker')
#nltk.download('words')
f = open('C:/Users/andy/Documents/CS+X/CS_X/week_12/hw_12/hitler.txt','r')
ex = f.readlines()
f.close()
len(ex)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ['Fate',
#  'Inn',
#  'Inn Inn',
#  'Lambach',
#  'soldieringBut',
#  'Realschol',
#  'orJ of',
#  'Realschule',
#  'Realschule Realschule',
#  'German Reich',
#  'GermanAustrians',
#  'unGerman',
#  'Habsburg',
#  'Habsburg GermanAustrian',
#  'Realschule House',
#  'Royal House',
#  'Habsburg House',
#  'Realschule Realschule Realschule',
#  'Fate Fate',
#  'Academy',
#  'Court Museum',
#  'Museum',
#  'Parliament',
#  'Academy Academy',
#  'School',
#  'Realschule Academy',
#  'Technic',
#  'Fate Goddess',
#  'Opera',
#  'Habsburg New World',
#  'culturaL',
#  'FFor',
#  'Fate Fate Nature',
#  'Frenchman',
#  'Fate Fate Fate',
#  'Social Democracy',
#  'Habsburg Anschluss',
#  'Social Democracy Slavic',
#  'Social Democracy Fate',
#  'Social Democratic Party',
#  'Social Democrats',
#  'depthsAt',
#  'Social Democracy Social Democratic',
#  'Social Democratic',
#  'Social Democracy Social',
#  'Social Democrats Social',
#  'Social Democratic Party Social',
#  'Social Democratic Party peopleThus',
#  'Social Democratic Party Fate',
#  'Social Democrats Social Democrats',
#  'Social Democratic Social Democratic',
#  'Social Democrats Social Democracy',
#  'Social',
#  'Realschule antiSemitic',
#  'Neue Freie',
#  'Hofburg',
#  'German Emperor',
#  'Reichstag',
#  'Reichstag German Kaiser',
#  'German',
#  'Deutsches Volksblatt',
#  'Volksblatt',
#  'antiSemitic',
#  'Christian Social',
#  'Christian Social Inner City',
#  'antiSemitic Inner City',
#  'Danube Canal',
#  'Zionistic',
#  'Black Death',
#  'Nature for',
#  'Social Democracy Fate Social Democratic',
#  'Marxist',
#  'Social Democratic Social Democratic Jew',
#  'Social Democracy Marxist',
#  'Fate Social Democracy',
#  'Fate Marxist',
#  'Almighty',
#  'Lord',
#  'Habsburg Empire',
#  'Empire',
#  'Empire German Empire',
#  'House',
#  'Fate IIX Roman Emperor',
#  'House Empire',
#  'Capuchin',
#  'Abgeordnetenhaus',
#  'Herrenhaus',
#  'Empire House',
#  'Lords',
#  'House Commons',
#  'Reichstag House',
#  'House Parliament',
#  'Social Democrats Social House',
#  'House House',
#  'Fate Habsburgs',
#  'House Fate',
#  'Emperor',
#  'Aphrodite',
#  'schafDopf',
#  'stupidityThus',
#  'Lord Pantheon',
#  'Habsburg Empire deGermanization',
#  'Archduke',
#  'Central Europe',
#  'Catholic',
#  'Habsburgs',
#  'House Catholic Church',
#  'PanGerman',
#  'House Vienna Court',
#  'Koniggratz',
#  'House Fate House',
#  'Slavization',
#  'antiGerman',
#  'Habsburgs Christian Social Party',
#  'Christian Social Party',
#  'German Reich Christian Social Party',
#  'Fate Christian Social',
#  'Habsburg Catholic Church',
#  'Clerical Party',
#  'clearlyAll',
#  'parliamentIt',
#  'Distress',
#  'Catholic House',
#  'Habsburgs Catholic',
#  'Catholic Church',
#  'Catholic Church Empire',
#  'Catholic Church German Socialist',
#  'PanGerman Catholic',
#  'Catholic Catholic',
#  'Church',
#  'Fate Catholic Church',
#  'Christian Social Christian Social Party',
#  'Church Christian Social Party',
#  'Christian Social Party Jew',
#  'Christian Social Party Habsburg',
#  'Christian Social Party Christian Social Party',
#  'Christian Social Party Habsburg German Reich',
#  'Fate German',
#  'Fate Fate SPRING',
#  'Hofbrauhaus',
#  'Pinakothek',
#  'Habsburg Golden Calf',
#  'Slavic',
#  'Empire Prague',
#  'Triple Alliance',
#  'Czechs',
#  'Nibelungen',
#  'Habsburgs Habsburgs',
#  'Triple',
#  'German Habsburgs',
#  'Habsburg Triple Alliance',
#  'SlavicHabsburg Empire',
#  'Quirinal',
#  'Vienna Hofburg',
#  'House Italians',
#  'Nature',
#  'Almighty Nature',
#  'Reich',
#  'American Union',
#  'American Union Teutonic Knights',
#  'possibilityIndustry',
#  'Englishman',
#  'Englishman Triple Alliance',
#  'Bismarck',
#  'unGerman Habsburg',
#  'Triple Alliance Particularly Ludendorff',
#  'Habsburgs Habsburg',
#  'Habsburg Habsburg',
#  'Pied Piper',
#  'Aryan',
#  'Englishman Empire',
#  'Marxist Socialist',
#  'Marxists',
#  'National Socialist',
#  'YOUNG',
#  'Wars',
#  'Liberation',
#  'Fate Balkan War',
#  'Archduke Francis Ferdinand',
#  'Empire Empire',
#  'Hofburg Fate',
#  'Emperor Habsburg',
#  'Fate Social Democrats',
#  'Center',
#  'liarThe',
#  'Habsburg Slavic',
#  'Empire German Reich',
#  'Goddess',
#  'Habsburg Fate',
#  'Niederwald Monument',
#  'List',
#  'Fate Reichstag',
#  'Republic',
#  'Socialist',
#  'Socialist Iron',
#  'Social Democracy Social Democracy',
#  'Social Democracy German',
#  "Nature 'aesthetic",
#  'Lord YEAR',
#  'Marne',
#  'Battle',
#  'Hermies',
#  'Fate Beelitz',
#  'Battle economyThe',
#  'Jew',
#  'Calamity Lanes',
#  'Vorwarts',
#  'Entente',
#  'Marxist Battle',
#  'Flanders',
#  'Entente Lord',
#  'Parliamentary',
#  'Flanders Battle',
#  'Somme',
#  'Englishman Englishman',
#  'Comines',
#  'Pasewalk',
#  'House House Almighty',
#  'Fate THE',
#  'Councils',
#  'Central Council',
#  'Second Infantry',
#  'Center Social Democracy',
#  'Social Marathon',
#  'National Socialists',
#  'Gottfried',
#  'Jew Karl Marx',
#  'Capital',
#  'Social Democracy Workers',
#  'Center Social',
#  'Center Entente',
#  'Center Sterneckerbrau',
#  'Workers',
#  'Second Infantry Babel',
#  'German Workers',
#  'Herrenstrasse',
#  'German Sterneckerbrau',
#  'Herr Harrer',
#  'Munich District',
#  'German German Workers',
#  'EXTENT',
#  'Reich Entente',
#  'Berlin Vorwarts',
#  'Roman Senate',
#  'Colonel Repington',
#  'Fate Kaiser',
#  'Marxist Social Democracy',
#  'Fate Majesty',
#  'Fate German Reich',
#  'Marxist Marxist',
#  'Frankfurter Zeitung',
#  'Jew Frankfurter Zeitung',
#  'Berliner',
#  'Bolshevistic',
#  'Central Germany',
#  'Ruhr',
#  'Court',
#  'Fate Republic',
#  'Parthenon',
#  'Bolshevistic Germanic Middle Ages',
#  'Pantheon',
#  'Gothic Cathedral',
#  'Reich Berlin Schloss',
#  'Reichstag Building',
#  'Mohammedan',
#  'Marxistic',
#  'Catholic Bismarck',
#  'Houston Stewart',
#  'Law',
#  'Defense',
#  'Republic German Reich',
#  'Reichstag Center',
#  'Flanders Marxist',
#  'General Staff',
#  'Reichstag Princess',
#  'Reich Republic',
#  'Nature Central',
#  'conceivableBut',
#  'Aryan Prometheus',
#  'Aryan Orient',
#  'Fate Fate Aryan',
#  'Aryan Aryan',
#  'Aryan Aryan Aryan',
#  'Aryan Jew',
#  'Jew Aryan',
#  'Aryan Jew Aryan',
#  'Talmud',
#  'Jew Esperanto',
#  'Wise Men',
#  'Frankfurter Zeitung Central',
#  'Jew Jew',
#  'Jew Jew Jew',
#  'Jew Jew Jew Jew',
#  'Marxist Marxist Jew',
#  'Jew Jew Marxist',
#  'Jew Negroes',
#  'Jew Reichstag',
#  'Marxist Marxist Marxist',
#  'Jean',
#  'Providence',
#  'THE',
#  'Versailles',
#  'Social Democracy Marxist Christianity',
#  'National Socialist German Reich',
#  'Munich Hofbrauhauskeller',
#  'Munich',
#  'Reds',
#  'Marxist Marxist Eberlbraukeller',
#  'Methuselah',
#  'Communist',
#  'Jew Left',
#  'National Socialist Red',
#  'Red',
#  'Red Center',
#  'Red German National People',
#  'Party',
#  'nationalThe',
#  'National Socialist National Socialist',
#  'Festsaal',
#  'Hofbrauhaus Communists',
#  'Germanic Siegfried',
#  'National Socialist Movement',
#  'Banquet Hall',
#  'Chariot',
#  'Fate Party',
#  'Reich House',
#  'House Puppets',
#  'Western Democracy',
#  'Marxists Marxist',
#  'Red International',
#  'Parliament Parliament',
#  'Parliament Centre',
#  'State',
#  'National Socialist Labour Party',
#  'State Marxist',
#  'Marxist State',
#  'Aryan Marxist',
#  'Marxist National Socialist',
#  'National Socialist First Period',
#  'Development',
#  'National Socialist National Socialist Movement',
#  'State State',
#  'State State State',
#  'Populist Party',
#  'State State State State',
#  'Habsburgs State',
#  'State State Laplanders',
#  'Eskimos',
#  'State National Socialists',
#  'State National Socialists National Socialists',
#  'State States',
#  'State Thirty Years',
#  'Dinaric',
#  'German Reich German Reich',
#  'State State State Nature',
#  'German State',
#  'Lord Christian Faith',
#  'Hottentots',
#  'Zulus',
#  'Kaffirs',
#  'Central Africa',
#  'People',
#  'People State',
#  'State State People',
#  'State State State Almighty',
#  'State People',
#  'State People People',
#  'German State People',
#  'People People',
#  'People People People',
#  'Fate People',
#  'People Gymnasium',
#  'High School',
#  'People People People People',
#  'State Republic',
#  'Republic Republic',
#  'People People Aryan',
#  'People People People State',
#  'People Bethmann',
#  'Catholic Church Church',
#  'Peoples',
#  'State Peoples',
#  'State National Socialist',
#  'Revolution',
#  'Republic Philosophy',
#  'Subjects',
#  'National Socialist Movement U.S.A.',
#  'People People State',
#  'State State German State',
#  'State Personality',
#  'Conception',
#  'Folkish',
#  'National Socialist Movement Conception',
#  'Folkish National Socialist People',
#  'State State Marxist',
#  'People National Socialist',
#  'State Marxist National Socialist',
#  'National Socialism',
#  'People People State People',
#  'People State National Socialist',
#  'Subjects Philosophy',
#  'Organization',
#  'National Socialist Movement People',
#  'Jew Aryan People',
#  'People Christianity',
#  'Marxist People',
#  'Catholic Church People',
#  'National Socialist Movement National Socialist German Labour Party',
#  'People National Socialist National Socialist',
#  'National Socialism National Socialist German Labour Party',
#  'National Socialist Movement National Socialism',
#  'German National Socialist Labour Party',
#  'National Socialist Party',
#  'National Socialist Movement Personality',
#  'Conception Folkish',
#  'Spoken Word',
#  'National Socialist Movement Spoken',
#  'Hofbrauhaus Hofbrau Haus',
#  'National Socialists Peace Treaty',
#  'Republic Versailles Treaty',
#  'National Socialist German Labour Party',
#  'German Press',
#  'Hecuba',
#  'Treaty',
#  'Treaty Treaty',
#  'Causes',
#  'Peace Treaties',
#  'Treaty Marxist',
#  'Marxist Marxist Social Democratic',
#  'Marxist Munich Kindl Keller',
#  'Oppression',
#  'Parsifal',
#  'Bayreuth',
#  'House Catholic',
#  'Communist Demagogue',
#  'Social Democrat',
#  'Communist Mass',
#  'Mass',
#  'National Socialist Philosophy',
#  'Organization Red',
#  'National Socialist Movement Red Front',
#  'Democrats',
#  'German People',
#  'Party Centre Party',
#  'Wagner Hall',
#  'Battle Professor X',
#  'Professor',
#  'National Socialist Red Flag',
#  'Bolshevism',
#  'Nationalist',
#  'Socialists',
#  'Gentlemen',
#  'Comrade',
#  'Left',
#  'National Socialist Red Jewish',
#  'Red Red',
#  'Red National Socialism',
#  'Red National Socialists',
#  'Marxists Reds',
#  'Red Left',
#  'National Socialist Revolution',
#  'Munich Burgerbrau',
#  'NSDAP',
#  'German National Socialist Labour Party International',
#  'Royal Palace',
#  'Lustgarten',
#  'State Social Democrats',
#  'Christian Socialists',
#  'Centre Party',
#  'Republic Republic National Socialists',
#  'Movement',
#  'German Federal',
#  'National Socialists National Socialist',
#  'Socialist Marxist',
#  'Munich Kindl Hall',
#  'Krone Circus Hall',
#  'Paris Agreement',
#  'London Ultimatum',
#  'Konig Platz',
#  'Red Feldherrn Hall',
#  'Munich Kindl Hall Krone Circus Hall',
#  'Hofbrauhaus Munich Hofbrau Banquet Hall',
#  'Downfall',
#  'Krone Circus Hall Circus Hall',
#  'Circus Hall',
#  'Landtag',
#  'Social Democratic Social Democratic Party',
#  'Munich Hofbrauhaus',
#  'Sternecker Gasse',
#  'Krone Circus',
#  'Hofbrauhaus Hall',
#  'Maffei Factory',
#  'Isar',
#  'Munchener',
#  'Sstruggle',
#  'Spoken Word Strong',
#  'National Socialist Movement Strong',
#  'Habsburg German Imperial Crown',
#  'Koniggratz German Reich',
#  'German Reich National Socialist German Labour Party',
#  'German Socialist',
#  'National Socialist German Labour Party German Socialist Party',
#  'National Socialist Party German Socialist Party',
#  'National Socialist German Labour Party National Socialist German Labour Party',
#  'National Socialists National Socialist German Labour Party',
#  'People Red',
#  'Organization National Socialist Movement',
#  'Organization Authority',
#  'Revolution State',
#  'Army',
#  'Army Armies',
#  'Soldiers',
#  'Revolution Revolution',
#  'Flanders German Revolution',
#  'Revolution Revolution Republic',
#  'Revolution Republic',
#  'Republic State',
#  'Revolution Revolution Revolution',
#  'Revolution Revolution Revolution People',
#  'Revolution Army',
#  'Revolution Army Armistice',
#  'Revolution Army Republic',
#  'State Revolution',
#  'Revolution Social',
#  'Social Democrats Social Democratic Party',
#  'Social Democratic Party Independent Socialist Party',
#  'Spartacist League',
#  'Social Democratic Party Revolution',
#  'Army Social Democratic',
#  'Independent Socialist',
#  'Spartacist',
#  'Marxist Marxist Republic',
#  'Republic Republic Spartacist',
#  'Bourgeoisie',
#  'Republic Revolution',
#  'State National Socialist Revolution',
#  'Marxists Revolution',
#  'Republic Army',
#  'Leagues',
#  'Defense Leagues',
#  'Jew Kyffauser',
#  'Marxist National Socialist German Labour Party',
#  'State State German State State',
#  'Marxist Marxist State',
#  'State Marxist Marxist',
#  'National Socialist Movement International',
#  'State Republic National Socialist Movement',
#  'Revolution Munich Hofbrauhaus',
#  'Movement Party',
#  'Movement Marxists',
#  'National Socialist Marxist',
#  'National Socialists Jewish Press',
#  'Red State',
#  'National Socialist German National Socialist Labour Party',
#  'State Army',
#  'Army Leipzig',
#  'Republic Revolution Revolution',
#  'German National Socialist Labour Party National Socialist Movement',
#  'National Socialist Movement National Socialism Marxist',
#  'Revolution Revolution National Socialist',
#  'Reichswehr',
#  'Movement Movement',
#  'Movement National Socialist People',
#  'Army Law',
#  'Republic National Socialist Movement',
#  'Party National Socialists',
#  'Reds Red Republic',
#  'National Socialist Movement German',
#  'German Congress',
#  'National Socialist Storm',
#  'German Communist Parties',
#  'Storm Troops',
#  'Republic Hofbrauhaus Keller',
#  'Fraternity',
#  'National Socialists Red',
#  'Comradesses',
#  'International Proletariat',
#  'Coburg Festival',
#  'Red Red Party',
#  'Red State National Socialist Movement',
#  'Marxist Republic',
#  'Marxist Marxist National Socialist',
#  'Coburg',
#  'Party Congress',
#  'Red Terror',
#  'National Socialist Storm Troops',
#  'Ruhr Ruhr',
#  'Movement German Reich',
#  'Storm Troops Movement',
#  'German National Socialist Labour Party Movement',
#  'National Socialist Strong',
#  'Federalism',
#  'National Socialist Movement North Germans',
#  'Army House',
#  'Metropolis',
#  'Reich Jew',
#  'Revolution Oriental',
#  'Reich Marxists',
#  'Party Marxist',
#  'Bavarian Worker',
#  'Bolshevik',
#  'Bavarian Legislative Diet',
#  'Communist Munich Lowenbrau Keller',
#  'Wagner Hall Sonnenstrasse',
#  'Reich Prussian State',
#  'Weimar',
#  'Weimar Constitution',
#  'Revolution Berlin',
#  'Jew Defence',
#  'National Socialist Movement Catholicism',
#  'Jew Catholic',
#  'Protestant',
#  'Creation',
#  'Protestant National Socialist Movement',
#  'Movement Bismarck',
#  'National Socialist National Socialist Movement Protestant',
#  'Catholic Centre Party',
#  'National Socialist Movement National Socialism American Union',
#  'American Union Union',
#  'Reich American Union',
#  'German Empire',
#  'Reichstag Reich',
#  'Reich Law',
#  'Republic Republic Reich',
#  'Reich Versailles Dictate',
#  'Reich Republic Republic',
#  'Republic Gessler',
#  'Republic Republic National Socialists Brandenburg',
#  'Napoleonic',
#  'National Socialists Sovereign Rights',
#  'Reich National Socialists',
#  'National Socialists National Socialist Movement',
#  'National Socialists Populist Party',
#  'Bavarian State',
#  'Reich State',
#  'Reich National Socialists diAerence',
#  'National Socialist Baden',
#  'Stuttgart',
#  'Rhine',
#  'Central Germany National Socialism',
#  'Churches',
#  'National Socialist Idea',
#  'National Socialist Organization',
#  'Propaganda',
#  'Organization National Socialist Movement German Labour Party',
#  'Weltanschhauung',
#  'Herrengasse',
#  'Gasteig',
#  'Party Tal',
#  'Bavarian Counsellors',
#  'Holy Roman Empire',
#  'Imperial Counsellors',
#  'Cornelius Strasse',
#  'Volkischer Beobachter',
#  'German National Socialist Labour Party Volkische Beobachter',
#  'Max Amann',
#  'Party National Socialist',
#  'Party National Socialists Volkische Beobachter',
#  'National',
#  'National Socialist Movement German National Socialist Labour Party',
#  'National Socialist Trades Union',
#  'National Socialism National Socialist Movement',
#  'National Socialist People',
#  'State Weimar Constitution',
#  'National Socialist National Socialist National Socialist',
#  'Central Economic Parliament',
#  'National Socialist National Socialist State',
#  'National Socialist Movement National Socialist',
#  'National Socialist National Socialist Trades Union',
#  'National Socialist National Socialist National Socialist Trades Union',
#  'State National Socialist Trades',
#  'National Socialist National Socialist National Socialist National Socialist Trades Union',
#  'National Socialist National Socialist Economic',
#  'Representative Chambers',
#  'Central Economic Parliament State',
#  'National Socialist Trades Union People',
#  'Nature National Socialist Trades Union',
#  'Trades Union',
#  'Marxist International Trades Union',
#  'Marxist Trades Union',
#  'Marxist Redeemer',
#  'Marxist Trades Union Marxist',
#  'National Socialist Valhalla',
#  'Regensburg',
#  'National Socialist Marxist Fate',
#  'National Socialist Movement National Socialist National Socialist',
#  'Marxist National Socialist Trades Union',
#  'Marxist Marxist Trades Union',
#  'Trades Union National Socialist Party',
#  'Propaganda Organization',
#  'National Socialist Movement Revolution',
#  'Revolution Reich',
#  'State German National Socialist Labour Party',
#  'State Continental Power',
#  'Roman Republic',
#  'Punic Wars',
#  'Continent',
#  'Army German Revolution',
#  'Empire Continental Power',
#  'Continent of Europe',
#  'Great Continental Power',
#  'Continental Power',
#  'Continental',
#  'Continent Atlantic',
#  'Mediterranean',
#  'Continent Continental Power',
#  'Balkanization',
#  'Continental Power German Central Europe',
#  'Red Bolshevik',
#  'Continent Zeppelins',
#  'Mediterranean Adriatic',
#  'Continent Marxist',
#  'Marxist German Reich',
#  'Bolshevization',
#  'European',
#  'Grande Nation',
#  'Wooden Horse',
#  'Jew Army',
#  'Vienna Rathaus Platz',
#  'Feldherrnhalle',
#  'Almighty God',
#  'Devil',
#  'Ruhr National Socialists',
#  'Movement Nibelungen',
#  'Habsburg Peace Treaty',
#  'Treaty Reich',
#  'German Reich National Socialism',
#  'Fascist',
#  'State Jew',
#  'Press',
#  'Seas',
#  'American State',
#  'Asiatic',
#  'Jewish',
#  'German Reich Jew',
#  'Old',
#  'Asiatic Englishman',
#  'Jewish Press',
#  'Jew National Socialist Movement',
#  'National Socialist Eastern Orientation',
#  'National Socialist Left',
#  'National Socialist workBut',
#  'National Socialists German Reich',
#  'German Reich American Union',
#  'German Reich German Reich German Reich',
#  'National Socialist National Socialist Hohenzollerns',
#  'National Socialists Congress',
#  'Union',
#  'National Socialists Fate',
#  'Fate National Socialists',
#  'National Socialists Fate National Socialist',
#  'National Socialist Oppressed Nations',
#  'God',
#  'Oppressed Nations',
#  'German Oppressed Nations',
#  'Empire AngloSaxon',
#  'German Schafkopf',
#  'Jew Marxist',
#  'National Socialist Entente',
#  'Entente National Socialists',
#  'Fate National Socialist',
#  'ARMISTICE',
#  'Drei Bekenntnisse',
#  'Treaty Clausewitz',
#  'Treaty Ruhr',
#  'Elbe',
#  'Hanover',
#  'Roar',
#  'Ruhr Fate',
#  'Ruhr Great',
#  'Ruhr Ruhr Ruhr',
#  'Napoleonic Moscow',
#  'Ruhr Versailles Treaty',
#  'Treaty Marxist Marxist',
#  'Marxist Marxist Fate',
#  'Marxist Alps',
#  'Marxists Ruhr',
#  'Ruhr Ruhr Marxist',
#  'Marxist Marxist Ruhr',
#  'Ruhr Ruhr National Socialists',
#  'Red Reichswehr',
#  'ConclusionON']

# %%
strEx = " ".join(str(x) for x in ex)
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent
sent = preprocess(strEx)

pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
tree1 = nltk.Tree('NP',['Alick'])
print(tree1)
tree2 = nltk.Tree('N',['Alick','Rabbit'])
print(tree2)
tree3 = nltk.Tree('S',[tree1,tree2])
print(tree3.label())
tree3.draw()
NER = ne_chunk(nltk.pos_tag(word_tokenize(strEx)), binary=False)
type(NER)

# %%
print(NER)

def get_continuous_chunks(text, label):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree and subtree.label() == label:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

# %%
get_continuous_chunks(strEx, 'GPE')
get_continuous_chunks(strEx, 'ORGANIZATION')
